# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('environmental_impact_asses_dataset.csv')
df.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df = pd.read_csv('environmental_impact_asses_dataset.csv')
#       2 df.describe()
#
# NameError: name 'pd' is not defined

# %%
condition = df['Area_Impacted'] > 150 
df=df[~condition]
condition = df['Area_Impacted'] < 50
df=df[~condition]
print(df)
# Out:
#            Project_ID       Project_Type Location  Area_Impacted  \
# 0           Project_1  Urban Development   City_E          75.11
# 3           Project_4             Energy   City_A          73.48
# 4           Project_5   Water Management   City_E          50.37
# 7           Project_8       Construction   City_C          53.58
# 9          Project_10             Energy   City_E          96.05
# ...               ...                ...      ...            ...
# 99994   Project_99995   Water Management   City_B          97.73
# 99995   Project_99996       Construction   City_D          88.73
# 99997   Project_99998             Energy   City_C          77.34
# 99998   Project_99999  Urban Development   City_C          85.22
# 99999  Project_100000  Urban Development   City_D          90.09
#
#        Air_Emissions  Water_Pollution  Habitat_Loss  Carbon_Footprint  \
# 0             772.98            30.68          7.24           1973.07
# ...

# %%
condition = df['Air_Emissions'] > 1448 
df=df[~condition]
condition = df['Air_Emissions'] < 501 
df=df[~condition]
print(df)
# Out:
#            Project_ID       Project_Type Location  Area_Impacted  \
# 0           Project_1  Urban Development   City_E          75.11
# 3           Project_4             Energy   City_A          73.48
# 4           Project_5   Water Management   City_E          50.37
# 9          Project_10             Energy   City_E          96.05
# 10         Project_11       Construction   City_E          56.48
# ...               ...                ...      ...            ...
# 99990   Project_99991   Water Management   City_B          70.92
# 99992   Project_99993       Construction   City_D          65.20
# 99993   Project_99994   Water Management   City_A          61.59
# 99994   Project_99995   Water Management   City_B          97.73
# 99999  Project_100000  Urban Development   City_D          90.09
#
#        Air_Emissions  Water_Pollution  Habitat_Loss  Carbon_Footprint  \
# 0             772.98            30.68          7.24           1973.07
# ...

# %%
condition = df['Water_Pollution'] > 144 
df=df[~condition]
condition = df['Water_Pollution'] < 40 
df=df[~condition]
print(df)
# Out:
#            Project_ID       Project_Type Location  Area_Impacted  \
# 9          Project_10             Energy   City_E          96.05
# 10         Project_11       Construction   City_E          56.48
# 13         Project_14       Construction   City_B          58.58
# 15         Project_16  Urban Development   City_C          72.41
# 17         Project_18             Energy   City_D          57.95
# ...               ...                ...      ...            ...
# 99990   Project_99991   Water Management   City_B          70.92
# 99992   Project_99993       Construction   City_D          65.20
# 99993   Project_99994   Water Management   City_A          61.59
# 99994   Project_99995   Water Management   City_B          97.73
# 99999  Project_100000  Urban Development   City_D          90.09
#
#        Air_Emissions  Water_Pollution  Habitat_Loss  Carbon_Footprint  \
# 9             691.45            49.58          7.74           3861.81
# ...

# %%
condition = df['Habitat_Loss'] > 14
df=df[~condition]
condition = df['Habitat_Loss'] < 4
df=df[~condition]
print(df)
# Out:
#            Project_ID       Project_Type Location  Area_Impacted  \
# 9          Project_10             Energy   City_E          96.05
# 10         Project_11       Construction   City_E          56.48
# 13         Project_14       Construction   City_B          58.58
# 15         Project_16  Urban Development   City_C          72.41
# 17         Project_18             Energy   City_D          57.95
# ...               ...                ...      ...            ...
# 99980   Project_99981     Transportation   City_B          76.24
# 99981   Project_99982             Energy   City_A          93.40
# 99993   Project_99994   Water Management   City_A          61.59
# 99994   Project_99995   Water Management   City_B          97.73
# 99999  Project_100000  Urban Development   City_D          90.09
#
#        Air_Emissions  Water_Pollution  Habitat_Loss  Carbon_Footprint  \
# 9             691.45            49.58          7.74           3861.81
# ...

# %%
condition = df['Carbon_Footprint'] > 8947
df=df[~condition]
condition = df['Carbon_Footprint'] < 7774
df=df[~condition]
print(df)
# Out:
#            Project_ID       Project_Type Location  Area_Impacted  \
# 88         Project_89  Urban Development   City_A          59.19
# 94         Project_95     Transportation   City_E          57.05
# 146       Project_147             Energy   City_A          88.37
# 206       Project_207   Water Management   City_A          94.27
# 291       Project_292             Energy   City_E          71.49
# ...               ...                ...      ...            ...
# 99691   Project_99692     Transportation   City_D          85.71
# 99693   Project_99694             Energy   City_D          81.32
# 99935   Project_99936       Construction   City_D          73.13
# 99938   Project_99939             Energy   City_C          85.08
# 99999  Project_100000  Urban Development   City_D          90.09
#
#        Air_Emissions  Water_Pollution  Habitat_Loss  Carbon_Footprint  \
# 88            596.56            51.49          8.16           7890.95
# ...

# %%
df
# Out:
#            Project_ID       Project_Type Location  Area_Impacted  \
# 88         Project_89  Urban Development   City_A          59.19
# 94         Project_95     Transportation   City_E          57.05
# 146       Project_147             Energy   City_A          88.37
# 206       Project_207   Water Management   City_A          94.27
# 291       Project_292             Energy   City_E          71.49
# ...               ...                ...      ...            ...
# 99691   Project_99692     Transportation   City_D          85.71
# 99693   Project_99694             Energy   City_D          81.32
# 99935   Project_99936       Construction   City_D          73.13
# 99938   Project_99939             Energy   City_C          85.08
# 99999  Project_100000  Urban Development   City_D          90.09
#
#        Air_Emissions  Water_Pollution  Habitat_Loss  Carbon_Footprint  \
# 88            596.56            51.49          8.16           7890.95
# ...

# %%
df
# Out:
#            Project_ID       Project_Type Location  Area_Impacted  \
# 88         Project_89  Urban Development   City_A          59.19
# 94         Project_95     Transportation   City_E          57.05
# 146       Project_147             Energy   City_A          88.37
# 206       Project_207   Water Management   City_A          94.27
# 291       Project_292             Energy   City_E          71.49
# ...               ...                ...      ...            ...
# 99691   Project_99692     Transportation   City_D          85.71
# 99693   Project_99694             Energy   City_D          81.32
# 99935   Project_99936       Construction   City_D          73.13
# 99938   Project_99939             Energy   City_C          85.08
# 99999  Project_100000  Urban Development   City_D          90.09
#
#        Air_Emissions  Water_Pollution  Habitat_Loss  Carbon_Footprint  \
# 88            596.56            51.49          8.16           7890.95
# ...

# %%
sorted_df = df.sort_values(by='Project_Type')

sorted_df
# Out:
#           Project_ID      Project_Type Location  Area_Impacted  Air_Emissions  \
# 65002  Project_65003      Construction   City_A          59.76         947.08
# 71501  Project_71502      Construction   City_A          51.09         504.75
# 71402  Project_71403      Construction   City_D          67.99         955.73
# 24429  Project_24430      Construction   City_D          83.06         988.77
# 71372  Project_71373      Construction   City_B          68.02         553.13
# ...              ...               ...      ...            ...            ...
# 31447  Project_31448  Water Management   City_C          95.49         657.05
# 54281  Project_54282  Water Management   City_D          70.22         968.16
# 83141  Project_83142  Water Management   City_B          65.25         942.71
# 31743  Project_31744  Water Management   City_D          81.96         607.60
# 64943  Project_64944  Water Management   City_A          85.54         663.02
#
# ...

# %%
sorted_df.to_csv('Clean.csv', index=False)
